# %% [markdown]
# # Credits
#
# <a href="https://www.udemy.com/course/100-days-of-code/">Dr. Angela Yu's 100 Days of Code</a>

# %% [markdown]
# # Description
#
# A simple program to calculate tips based on splitting a bill between `x` people

# %% [markdown]
# # Code

# %%
def welcome_msg():
    print("Welcome to TIP Calculator Project!")

# %%
def ask_questions():
    total_bill = float(input("What is your total bill ? $"))
    tip = float(input("Write the percentage of tip you'd like to give? 10/12/15 ?"))
    n_people = float(input("How many people to split the bill? "))
    
    return (total_bill, tip, n_people)

# %%
def tip_calculator():
    welcome_msg()
    
    total_bill, tip, n_people = ask_questions()
    total_tip = (total_bill / n_people) * (1 + tip/100) 
    total_tip = round(total_tip,2)
    
    print(f"Each person can pay ${total_tip}.")

# %%
tip_calculator()
# Out:
# Welcome to TIP Calculator Project!
# What is your total bill ? $1000
# Write the percentage of tip you'd like to give? 10/12/15 ?12
# How many people to split the bill? 10
# Each person can pay $112.0.
